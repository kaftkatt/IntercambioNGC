# %%
import numpy as np
import array
import sys
import matplotlib.pyplot as plt
from math import sin
import cmocean
import gsw
import pylab as pl

# %%
dtype=np.float32

Ho=1280  # ocean depth in meters
nx=10    # number of gridpoints in x-direction
ny=250    # number of total gridpoints in y-direction
nyS=10

OB=25 #Define where to start with stratified profile in sponge

nz=80     # number of gridpoints in z-direction
nt=12 #nt=10  #for 3 years with timestep 60 s

dx=2
dz=16

dy=np.linspace(3,0.5,50)
dy=np.append(dy,np.ones(100)*0.5)
dy=np.append(dy,np.linspace(0.5,5,100))


y=np.cumsum(dy)
x=np.arange(0,nx*dx,dx)
z=np.arange(0,nz*dz,dz)
umbral=ny*0.4
lat=(22.92+31.70)/2

omega=7.2921*(10**(-5))

f=2*omega*sin(np.deg2rad(lat))

def gaussian(x, mu, sig):
    return (
         np.exp(-np.power((x - mu) / sig, 2.0) / 2)
    )


#Values of salinity at open boundary
salBo=np.zeros((nx,nz,nt),dtype=dtype)

#Bathymetry definition
dep=(gaussian(y,y[int(umbral)], 10)*800-Ho)
ho=np.tile(dep,(nx,1))
ho[0,:]=0
ho[-1,:]=0

# %% [markdown]
# # One peak

# %%
nyIn=80

dyIn=np.zeros(nyIn)
dyIn[0]=500
for i in np.arange(1,nyIn,1):
    if dyIn[i-1]<5000:
        dyIn[i] = dyIn[i-1] + dyIn[i-1]*0.025
    else:
        dyIn[i] = dyIn[i-1]

ny=320
dy=np.zeros(ny)

dy[:70]=np.flip(dyIn[:-10])
dy[70:240]=500
dy[240:320]=dyIn

# %%
y=np.cumsum(dy)
depIN=(gaussian(y,y[int(ny*0.485)], 8000)*880-Ho)
#dep=np.append(depIN,np.ones(320-288)*-Ho)
ho=np.tile(depIN,(nx,1))
ho[0,:]=0
ho[-1,:]=0

# %%
ho[5][np.argmax(ho[5])]
y[np.argmax(ho[5])]-y[20]
# Out:
# np.float64(90065.53599421566)

# %%
#dyTest=np.append(dy,np.ones(320-288)*dyIn[-1])
y=np.cumsum(dy)
fig,ax=plt.subplots()
ax.plot(y/1000,dy/1000)
ax.minorticks_on()

ax.grid(which='both',alpha=0.7)
ax1=ax.twinx()
ax1.plot(y/1000,ho[5],'k')
ax1.axvline(y[20]/1000)
ax1.axvline(y[-20]/1000)

# %%
temp=tempS*np.ones((nx,ny,nz),dtype=dtype)
#temp[:,:OB,:]=tempS
#temp[:,-OB:,:]=tempN

# %% [markdown]
# #### Flux stronger between the sills

# %%
nyIn=80

dyIn=np.zeros(nyIn)
dyIn[0]=500
for i in np.arange(1,nyIn,1):
    dyIn[i] = dyIn[i-1] + dyIn[i-1]*0.025

ny2=250
dyIn2=np.zeros(ny2)

dyIn2[:80]=np.flip(dyIn)
dyIn2[80:250]=500

dy=np.append(dyIn2,np.flip(dyIn2))
y=np.cumsum(dy)

# %%
ny=500
nx=40
out=np.tile(gaussian(np.arange(0,ny,1),len(y)/2,40),(nx,1))

Q=np.zeros((nx,ny,nt), dtype=dtype)
for i in range(12):
    Q[:,:,i]=out*-76*((gaussian(np.arange(12), 5.5, 2)-np.min(gaussian(np.arange(12), 5.5, 2)))*5)[11-i]

# %%
np.mean(Q)
# Out:
# np.float32(-30.02034)

# %%
cax=plt.pcolormesh(Q[:,:,6])
plt.colorbar(cax)

# %% [markdown]
# #### Same flux over the whole basin

# %%
nx=40    # number of gridpoints in x-direction
ny=320 
Q=np.zeros((nx,ny,nt))
Qin=-83*(gaussian(np.arange(12), 5.5, 2))
Q[:,20:-20,:]=np.tile(Qin,(nx,ny-40,1))

# %%
print(fr'{-np.mean(Q):.1f} W/')
# Out:
# 30.3 W/

# %%
plt.pcolormesh(Q[20,:,:])

# %%
Ho=1280  # ocean depth in meters
nx=40    # number of gridpoints in x-direction
ny=300    # number of total gridpoints in y-direction
nyS=20

nz=80     # number of gridpoints in z-direction
nt=12 #nt=10  #for 3 years with timestep 60 s

dx=0.5
dz=16



x=np.arange(0,nx*dx,dx)
z=np.arange(0,nz*dz,dz)



indzSill=len(z[z<-np.max(ho[ho!=0])])
tempN=np.zeros(nz)
tempN[:indzSill]=np.arange(15,13,(13-15)/indzSill)
tempN[indzSill-1:]=np.arange(tempN[indzSill-1],11,(10.99-tempN[indzSill-1])/(len(tempN[indzSill-1:])))
tempBoN=np.tile(np.tile(tempN,(nx,1)).T,(nt,1,1)).T

#Values of temperature at open boundary SOUTH
indz600=len(z[z<600])
tempS=np.zeros(nz)
tempS[:indzSill]=np.arange(16,8.5,(8.5-16)/indzSill)
tempS[indzSill-1:indz600]=np.arange(tempS[indzSill-1],7,(7-tempS[indzSill-1])/(len(tempS[indzSill-1:indz600])))
tempS[indz600-1:]=np.arange(tempS[indz600-1],5,(5.02-tempS[indz600-1])/(len(tempS[indz600:])))
tempBoS=np.tile(np.tile(tempS,(nx,1)).T,(nt,1,1)).T

# %%
tempS[z==400]
# Out:
# array([8.67142857])

# %%
plt.plot(tempN,-z)
plt.plot(tempS,-z)

# %%
params = {'font.size': 15,
          'figure.figsize': (10, 5),
         'font.family':'sans'}
pl.rcParams.update(params)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
project='twoBumps'
ed='run3/'

# %%
sponge=True
spongeN=True


fig3,ax = plt.subplots()

ax.plot(y/1000,ho[1,:],'green',label='Depth [m]')

ax1=ax.twiny()
ax1.plot(tempN,-z,'red',label='Northern boundary')
ax1.plot(tempS,-z,'blue',label='Southern boundary')
ax1.set(xlabel='Temperature [degC]')

ax2=ax.twinx()
ax2.plot(y/1000,dyTest,'k',label='Resolution in y', linestyle='dashed')
ax.minorticks_on()

ax.set(xlabel='Distance [km]',ylabel='Depth [m]')
ax.minorticks_on()

fig3.legend(bbox_to_anchor=[0.4, 0.9])

if sponge=='True':
        ax.axvline(y[nyS]/1000,linestyle='dashed',c='brown',linewidth=1)
        ax.text(y[nyS]/1000+5,-200, 'Sponge\nend', va='center',color='brown',fontsize='small')
if spongeN=='True':
        ax.axvline(y[-nyS]/1000,linestyle='dashed',c='brown',linewidth=1)
        ax.text(y[-nyS]/1000+5,-200, 'Sponge\nend', va='center',color='brown',fontsize='small')

ax.grid(which='major',alpha=0.7)

plt.savefig('../' + str(project)+'/Figures/' + str(ed)+ 'inputStrat.png', bbox_inches='tight')

# %%
-np.max(ho[ho!=0])
# Out:
# np.float64(400.0)

# %% [markdown]
# # Two peaks

# %%
nyIn=70

dyIn=np.zeros(nyIn)
dyIn[0]=500
for i in np.arange(1,nyIn,1):
    dyIn[i] = dyIn[i-1] + dyIn[i-1]*0.025

ny=250
dy=np.zeros(ny)

dy[:70]=np.flip(dyIn)
dy[70:250]=500

# %% [markdown]
# #### Same height

# %%
y=np.cumsum(dy)

depIN=(gaussian(y,y[int(ny*0.55)], 8000)*880-Ho)
dep=np.append(depIN,np.flip(depIN))
ho=np.tile(dep,(nx,1))
ho[0,:]=0
ho[-1,:]=0

# %% [markdown]
# #### Different heights

# %%
y=np.cumsum(dy)

depIN=(gaussian(y,y[int(ny*0.55)], 8000)*880-Ho)
depIN2=(gaussian(y,y[int(ny*0.55)], 8000)*680-Ho)
dep=np.append(depIN,np.flip(depIN2))
ho=np.tile(dep,(nx,1))
ho[0,:]=0
ho[-1,:]=0

# %%
np.max(ho[5][180:])
# Out:
# np.float64(-600.0)

# %%
dyTest=np.append(dy,np.flip(dy))
y=np.cumsum(dyTest)
fig,ax=plt.subplots()
ax.plot(y/1000,dyTest/1000)
ax1=ax.twinx()
ax1.plot(y/1000,ho[5],'k')
ax1.axvline(y[int(ny*0.55)]/1000)
ax1.axvline(y[-int(ny*0.55)]/1000)
#ax1.axvline(y[20]/1000)
#ax1.axvline(y[-20]/1000)
ax.text(y[int(len(y)*0.4)]/1000,3,f'{(y[int(ny*0.55)]/1000-y[-int(ny*0.55)]/1000):.1f} km\n between\n peaks')
ax.minorticks_on()

ax.grid(which='both',alpha=0.7)

# %% [markdown]
# # Realistic bathymetry

# %%
nyIn=70

dyIn=np.zeros(nyIn)
dyIn[0]=500
for i in np.arange(1,nyIn,1):
    dyIn[i] = dyIn[i-1] + dyIn[i-1]*0.025

ny=250
dy=np.zeros(ny)

dy[:70]=np.flip(dyIn)
dy[70:250]=500

# %%
y=np.cumsum(dy)

depIN=(gaussian(y,y[int(ny*0.55)], 8000)*880-Ho)
depIN2=(gaussian(y,y[int(ny*0.55)], 8000)*680-Ho)
dep=np.append(depIN,np.flip(depIN2))
ho=np.tile(dep,(nx,1))
ho[0,:]=0
ho[-1,:]=0

# %%
indend2sill=np.where(ho[5]>-1000)[0][-1]

# %%
dyTest=np.append(dy,np.flip(dy))
y=np.cumsum(dyTest)
fig,ax=plt.subplots()
ax.plot(y/1000,dyTest/1000)
ax1=ax.twinx()
ax1.plot(y/1000,ho[5],'k')
ax1.axvline(y[int(ny*0.55)]/1000)
ax1.axvline(y[-int(ny*0.55)]/1000)
ax1.axvline(y[indend2sill]/1000)
#ax1.axvline(y[-20]/1000)
ax.text(y[int(len(y)*0.4)]/1000,3,f'{(y[int(ny*0.55)]/1000-y[-int(ny*0.55)]/1000):.1f} km\n between\n peaks')
ax.minorticks_on()

ax.grid(which='both',alpha=0.7)

# %% [markdown]
# # Other

# %%
Ho=1280  # ocean depth in meters
nx=1    # number of gridpoints in x-direction
ny=240    # number of gridpoints in y-direction
nz=160     # number of gridpoints in z-direction
nt=12 #nt=10  #for 3 years with timestep 60 s

dx=1
dy=1
dz=8

dtype=np.float32

x=np.arange(0,nx*dx,dx)
y=np.arange(0,ny*dy,dy)
z=np.arange(0,nz*dz,dz)

lat=(22.92+31.70)/2

omega=7.2921*(10**(-5))

f=2*omega*sin(np.deg2rad(lat))

def gaussian(x, mu, sig):
    return (
         np.exp(-np.power((x - mu) / sig, 2.0) / 2)
    )

# %%
#Defining inital temperature difference
temp=15*np.ones((nx,ny,nz),dtype=dtype)
temp[:,int(ny*0.5):,:]=temp[:,int(ny*0.5):,:]+1

#Q created to make the plot something
Q=np.zeros((nx,ny,nt),dtype=dtype)

#Values of temperature at open boundary
tempBo=15*np.ones((nx,nz,nt),dtype=dtype)

#Values of salinity at open boundary
salBo=np.zeros((nx,nz,nt),dtype=dtype)

#Bathymetry definition
dep=(gaussian(np.arange(ny), ny/2, 10)*800-Ho)
ho=np.tile(dep,(nx,1))
ho[:,-1]=0

# %%
plt.plot(ho[0])

# %%
project='SaddlePoint'
location='/Users/ameliaking/Proyecto/Codigo/NGC/' + str(project)

# %%
def write_with_byte_inversion(f, tab):
    tab2write = array.array('f', tab.T.flatten())
    if sys.byteorder == 'little':
        tab2write.byteswap()
    f.write(tab2write)

dtype=np.float32

if project == 'Sponge':

    Ho=600  # ocean depth in meters
    #Sponge
    nx=40    # number of gridpoints in x-direction

    #Prior to Sponge
    #nx=20    # number of gridpoints in x-direction

    ny=120    # number of gridpoints in y-direction
    nz=10     # number of gridpoints in z-direction
    nt=12 #nt=10  #for 3 years with timestep 60 s

    #Sponge
    dx=2.5 #km
    #Prior to Sponge
    #dx=5

    dy=5  #km
    dz=60 #m

    x=np.arange(0,nx*dx,dx)
    y=np.arange(0,ny*dy,dy)
    z=np.arange(0,nz*dz,dz)
elif project =='SaddlePoint':
    Ho=1200  # ocean depth in meters
    #Sponge
    nx=1    # number of gridpoints in x-direction
    ny=240    # number of gridpoints in y-direction
    nz=80     # number of gridpoints in z-direction
    nt=12 
    
    dx=1 #km
    dy=1  #km
    dz=15   #m

    x=np.arange(0,nx*dx,dx)
    y=np.arange(0,ny*dy,dy)
    z=np.arange(0,nz*dz,dz)
    
    
lat=(22.92+31.70)/2

omega=7.2921*(10**(-5)) 

f=2*omega*sin(np.deg2rad(lat))

# %% [markdown]
# ## Functions

# %%
def gaussianold(x, mu, sig):
    return (
        1.0 / (np.sqrt(2.0 * np.pi) * sig) * np.exp(-np.power((x - mu) / sig, 2.0) / 2)
    )

def gaussian(x, mu, sig):
    return (
        np.exp(-np.power((x - mu) / sig, 2.0) / 2)
    )

# %%
def gauss2d(mat, sigma, center):
    gsize = np.shape(mat)
    [R,C] = np.meshgrid(np.arange(0,gsize[0],1),np.arange(0,gsize[1],1))
    mat = gaussC(R,C, sigma, center)
    return mat

def gaussC(x, y, sigma, center):
    xc = center[0]
    yc = center[1]
    exponent = (np.power((x-xc),2) + np.power((y-yc),2))/np.power(sigma,2)
    val= np.exp(-exponent)
    return val

# %% [markdown]
# #### Heatflux Gaussian

# %%
#Heatflux Gaussian
mu=200
sig=60

Q=np.zeros((nx,ny,nt), dtype=dtype)
Q[:,:,0]=np.flip(-14000*gaussianold(y, mu, sig))
Q[:,:,1]=np.flip(-14000*gaussianold(y, mu, sig))

# %% [markdown]
# #### Spall

# %%
X,Xno=np.meshgrid(x,y)

# %%
out=gauss2d(X,100,[80,nx/2])

# %%
plt.plot((gaussianold(np.arange(12), 5.5, 2)-np.min(gaussianold(np.arange(12), 5.5, 2)))*5)

# %%
Q=np.zeros((nx,ny,nt), dtype=dtype)
for i in range(12):
    Q[:,:,i]=out*-300*((gaussianold(np.arange(12), 5.5, 2)-np.min(gaussianold(np.arange(12), 5.5, 2)))*5)[11-i]

#450 noRBCS
#950 SpallGaussianOverTime

# %%
np.mean(Q[:,20:,:])
# Out:
# -17.669344

# %%
plt.pcolormesh(Q[:,:,10])

# %%
mu=0
sig=30


T_mask=np.zeros((nx,ny,nz), dtype=dtype)
maskin=gaussianold(y, mu, sig)*100
T_mask[:,0:30,:]=maskin[None,0:30,None]/np.max(maskin)

# %%
tempRelax=15*np.ones((nz,ny,nx),dtype=dtype)

# %% [markdown]
# # Bathymetry

# %% [markdown]
# #### Saddle point

# %% [markdown]
# Original

# %%
dep=gaussianold(np.arange(120), 40, 7)*7890-600

# %% [markdown]
# Ballenas Channel

# %%
dep=gaussianold(np.arange(120), 60, 2)*5500-1500

# %%
max(dep)
# Out:
# -402.90872889606

# %%
ho=np.tile(dep,(nx,1))
ho[0,:]=0
ho[-1,:]=0
ho[:,-1]=0

# %%
params = {'font.size': 8,
          'figure.figsize': (15, 4),
         'font.family':'sans'}
pl.rcParams.update(params)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
plt.plot(y,ho[10,:])
plt.axvline(y[15])
plt.axvline(y[55])
plt.axvline(y[60])
plt.axvline(y[65])

# %%
y[55]-y[65]
# Out:
# -50

# %% [markdown]
# Ballenas channel??
#
# upplösning 2 km i y
# 750 m i x

# %%
plt.pcolormesh(ho)
plt.colorbar()

# %% [markdown]
# #### Flat bottom

# %%
ho=-Ho*np.ones((nx,ny),dtype=dtype)
ho[0,:]=0
ho[-1,:]=0
ho[:,-1]=0

# %% [markdown]
# # OBCS temperature

# %%
#OBCS

tempBo=15*np.ones((nx,nz,nt),dtype=dtype)

# %% [markdown]
# ### Intent with Z being equally spaced, Heatflux just a block

# %%
ho=-Ho*np.ones((nx,ny),dtype=dtype)
ho[0,:]=0
ho[-1,:]=0
ho[:,-1]=0

# %%
Q=np.zeros((nx,ny,nt), dtype=dtype)
Q[:,70:90,1]=-80

# %%
strat=np.ones(ny)*15

# %% [markdown]
# ### Sponge

# %%
X,Xno=np.meshgrid(x,y)
out=gauss2d(X,100,[80,10])
Q=np.zeros((nx,ny,nt), dtype=dtype)
for i in range(12):
    Q[:,:,i]=out*-300*((gaussianold(np.arange(12), 5.5, 2)-np.min(gaussianold(np.arange(12), 5.5, 2)))*5)[11-i]

# %%
#Input temperature
temp=15*np.ones((nz,ny,nx),dtype=dtype)

#Values of temperature at open boundary
tempBo=15*np.ones((nx,nz,2),dtype=dtype)

#Bathymetry definition
ho=-Ho*np.ones((nx,ny),dtype=dtype)
ho[0,:]=0
ho[-1,:]=0
ho[:,-1]=0

# %%
#Input Velocities at open Boundary
u0 = .25
uMerid=u0*np.ones((nx,nz,2),dtype=dtype)

# %% [markdown]
# # Plotting

# %%
params = {'font.size': 10,
          'figure.figsize': (6, 8),
         'font.family':'sans'}
pl.rcParams.update(params)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
fig3 = plt.figure(constrained_layout=True)
gs = fig3.add_gridspec(2, 5)
ax = fig3.add_subplot(gs[0, 0:2])


ax.plot(range(nt),Q[20,80,:],'k' )
ax.set(xlabel='Time [Months]',ylabel='Heatflux [W/m$^2$]')
ax.minorticks_on()

#ax.grid(which='minor',linestyle='--', alpha=0.5,)
ax.grid(which='major',alpha=0.7)

ax.text(0, 1.05, '(a)', fontweight='bold', color='k', 
        transform=ax.transAxes)

ax = fig3.add_subplot(gs[1, 0:2])

ax.plot(tempBo[20,:,0],-z )
ax.set(xlabel='Temperature [°C]',ylabel='Depth [m]')
ax.text(0, 1.05, '(b)', fontweight='bold', color='k', 
        transform=ax.transAxes)


ax = fig3.add_subplot(gs[:, 2])

colors=cmocean.cm.solar(np.linspace(0, 1, 3))
cax=ax.pcolormesh(x,y,Q[:,:,5].T,cmap=cmocean.cm.solar)

cbar= plt.colorbar(cax)
cbar.set_label('Heatflux [W/m$^2$]')
ax.set(xlabel='Distance [km]',ylabel='Distance [km]')
ax.set_facecolor(colors[-3])

plt.gca().set_aspect('equal')
ax.set_xlim((-(100-max(x)),100))


ax.scatter(x[0],y[80],marker='*',c='yellow',linewidth=1)
ax.text(x[0],y[85]+2, 'Heatflux\nOver time', va='center',color='yellow',fontsize='small')

ax.axhline(y[15],linestyle='dashed',c='brown',linewidth=1)
ax.text(x[0],y[15]+2, 'Sponge\nend', va='center',color='brown',fontsize='small')

ax.text(-0.3, 1, '(b)', fontweight='bold', color='k', 
        transform=ax.transAxes)

ax = fig3.add_subplot(gs[:, 4])

colors=cmocean.cm.deep(np.linspace(0, 1, 3))

cax=ax.pcolormesh(x,y,-ho.T,cmap=cmocean.cm.deep)

plt.gca().set_aspect('equal')
ax.set_xlim((-(100-max(x)),100))


cbar= plt.colorbar(cax)
cbar.set_label('Depth [m]')
ax.set(xlabel='Distance [km]')
ax.yaxis.set_tick_params(labelleft=False)
ax.set_facecolor(colors[0])
ax.text(0, 1.05, '(c)', fontweight='bold', color='k', 
        transform=ax.transAxes)

#ax = fig3.add_subplot(gs[:, 4])

#cax=ax.pcolormesh(x,y,T_mask[0,:,:].T)
#ax.axis('equal')
#cbar= plt.colorbar(cax)
#cbar.set_label('Restoring temperature area ')
#ax.set(xlabel='Distance [km]')
#ax.yaxis.set_tick_params(labelleft=False)


#plt.savefig(str(location)+'/Figures/InputVars.png', bbox_inches='tight')
# Out:
# Text(0, 1.05, '(c)')

# %% [markdown]
# ## Sill

# %%
plt.plot(gaussian(np.arange(12), 5.5, 2))

# %%
import numpy as np
import array
import sys
import matplotlib.pyplot as plt
from math import sin
import pylab as pl

sponge='True'

project='2DsillOB'
location='/HOME/users/amelia.th/Model/IntercambioNGC/'
run='/run7/'
def write_with_byte_inversion(f, tab):
    tab2write = array.array('f', tab.T.flatten())
    if sys.byteorder == 'little':
        tab2write.byteswap()
    f.write(tab2write)

dtype=np.float32

Ho=1200  # ocean depth in meters
nx=1    # number of gridpoints in x-direction
ny=240    # number of gridpoints in y-direction
nz=80     # number of gridpoints in z-direction
nt=12 #nt=10  #for 3 years with timestep 60 s

dx=1
dy=1
dz=12

x=np.arange(0,nx*dx,dx)
y=np.arange(0,ny*dy,dy)
z=np.arange(0,nz*dz,dz)

lat=(22.92+31.70)/2

omega=7.2921*(10**(-5)) 

f=2*omega*sin(np.deg2rad(lat))

def gaussian(x, mu, sig):
    return (
         np.exp(-np.power((x - mu) / sig, 2.0) / 2)
    )

#Defining heatflux

out=gaussian(y, 0.75*ny, 10)
Q=np.zeros((nx,ny,nt), dtype=dtype)
for i in range(12):
    Q[:,:,i]=-750*out*(gaussian(np.arange(12), 5.5, 2)-np.min(gaussian(np.arange(12), 5.5, 2)))[11-i]

#Values of temperature at open boundary 
tempBo=15*np.ones((nx,nz,nt),dtype=dtype)

#Values of salinity at open boundary
salBo=np.zeros((nx,nz,nt),dtype=dtype)

#Bathymetry definition
dep=(gaussian(np.arange(ny), ny/2, 10)*800-Ho)
ho=np.tile(dep,(nx,1))
ho[:,-1]=0

# %%
np.mean(Q)
# Out:
# -30.859728

# %%
#### Plotting #####
fig3 = plt.figure()
gs = fig3.add_gridspec(2, 5)
ax = fig3.add_subplot(gs[0, 0:2])
params = {'font.size': 10,
          'figure.figsize': (8, 6),
         'font.family':'sans'}
pl.rcParams.update(params)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

ax.plot(y,Q[0,:,6],'k' )
ax.set(xlabel='Distance [km]',ylabel='Heatflux [W/m$^2$]')
ax.minorticks_on()

if sponge=='True':
        ax.axvline(y[20],linestyle='dashed',c='brown',linewidth=1)
        ax.text(0,y[20]+2, 'Sponge\nend', va='center',color='brown',fontsize='small')


ax.grid(which='major',alpha=0.7)

ax.text(0, 1.02, '(a)', fontweight='bold', color='k', 
        transform=ax.transAxes)

ax = fig3.add_subplot(gs[1, 0:2])

ax.plot(tempBo[0,:,0],-z )
ax.set(xlabel='Temperature [°C]',ylabel='Depth [m]')
ax.text(0, 1.02, '(b)', fontweight='bold', color='k', 
        transform=ax.transAxes)


ax = fig3.add_subplot(gs[:, 2])

cax=ax.pcolormesh(y,range(nt),Q[0,:,:].T)

cbar= plt.colorbar(cax)
cbar.set_label('Heatflux [W/m$^2$]')
ax.set(xlabel='Distance [km]',ylabel='Distance [km]')
if sponge=='True':
	ax.axvline(y[20],linestyle='dashed',c='brown',linewidth=1)
	ax.text(0,y[20]+2, 'Sponge\nend', va='center',color='brown',fontsize='small')

ax.text(-0.3, 1.02, '(c)', fontweight='bold', color='k', 
        transform=ax.transAxes)

ax = fig3.add_subplot(gs[:, 4])

cax=ax.pcolormesh(-ho.T)

if sponge=='True':
	ax.axhline(y[20],linestyle='dashed',c='white',linewidth=1)
	ax.text(0,y[20]+2, 'Sponge\nend', va='center',color='white',fontsize='small')


cbar= plt.colorbar(cax)
cbar.set_label('Depth [m]')
ax.set(xlabel='Distance [km]')
ax.yaxis.set_tick_params(labelleft=False)
ax.text(0, 1.02, '(d)', fontweight='bold', color='k', 
        transform=ax.transAxes)

#plt.savefig('test.png')

plt.tight_layout()
#plt.savefig(str(location)+str(project)+'/Figures'+str(run)+'InputVars.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(gaussian(y, 0.75*ny, 10)*-500)

# %%
out=gaussian(y, 0.75*ny, 10)
Q=np.zeros((nx,ny,nt), dtype=dtype)
for i in range(12):
    Q[:,:,i]=-750*out*(gaussian(np.arange(12), 5.5, 2)-np.min(gaussian(np.arange(12), 5.5, 2)))[11-i]

# %%
np.mean(Q[:,:,:])
# Out:
# -30.859728

# %%
plt.pcolormesh(y,range(nt),Q[0,:,:].T)
plt.colorbar()

# %%
#Defining heatflux

T,Y=np.meshgrid(np.arange(12),y)
out=gaussian(y, 0.75*ny, 10)
Q=np.zeros((nx,ny,nt), dtype=dtype)
for i in range(12):
    Q[:,:,i]=-600*out*(gaussian(np.arange(12), 5.5, 2)-np.min(gaussian(np.arange(12), 6, 3)))[11-i]

#Defining Relaxation mask
#Input temperature
temp=np.zeros((nx,ny,nz),dtype=dtype)
tempLin1=np.tile(30 - z/(z[-1]/(30-6)),(int(ny/2),1))
tempLin2=np.tile(30 - z/(z[-1]/(30-12)),(int(ny),1))
#temp[:,:int(ny/2),:]=tempLin1
temp[:,:,:]=tempLin2


#Values of temperature at open boundary
tempBo=15*np.ones((nx,nz,nt),dtype=dtype)

#Values of salinity at open boundary
salBo=np.zeros((nx,nz,nt),dtype=dtype)

#Bathymetry definition
dep=gaussian(np.arange(ny), ny/2, 10)*20000-Ho
ho=np.tile(dep,(nx,1))

indDep=np.where(dep>-800)[0][0]

dep2=dep[indDep]*np.ones((nx,ny))
dep2[:,indDep:]=dep[indDep:]
# Out:
#   Cell In[54], line 7
#     Q[:,:,i]=-600*out*(gaussian(np.arange(12), 5.5, 2)-np.min(gaussian(np.arange(12), 6, 3))[11-i]
#                       ^
# SyntaxError: '(' was never closed

# %%
np.mean(Q)
# Out:
# -24.59174

# %%
tempBo=np.zeros((nx,nz,nt),dtype=dtype)
tempBo[:,:,:]=np.tile(tempLin2[0],(nt,1)).T

# %%
plt.pcolormesh(tempBo[0])

# %%
plt.plot(temp[0,int(ny/2),:],-z)

# %%
params = {'font.size': 10,
          'figure.figsize': (10, 5),
         'font.family':'sans'}
pl.rcParams.update(params)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
plt.pcolormesh(y,-z,temp[0].T)
plt.plot(y,ho[0],'k')
plt.plot(y,dep2[0],'r')
plt.colorbar()

# %%
tAlpha=2e-4
sBeta=0
dens1=gsw.density.rho(salBo[0,:,0], temp[0,1,:], z)
dens2=gsw.density.rho(salBo[0,:,0], temp[0,-1,:], z)

# %%
fig,ax=plt.subplots()


ax.plot(temp[0,1,:],-z,color='tab:purple',label='south of the sill')
ax.plot(temp[0,-1,:],-z,color='tab:green',label='north of the sill')

ax1=ax.twiny()

ax1.plot(dens1,-z,color='tab:purple',linestyle='dashed')
ax1.plot(dens2,-z,color='tab:green',linestyle='dashed')

ax.set(xlabel='Temperature [°C]', ylabel='Depth [m]')
ax1.set(xlabel='Density [kg/m$^3$]')
ax.minorticks_on()

ax.grid(which='minor',linestyle='--', alpha=0.5)
ax.grid(which='major',alpha=0.7)
ax.legend()

# %%
params = {'font.size': 10,
          'figure.figsize': (8, 6),
         'font.family':'sans'}
pl.rcParams.update(params)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
y[int(ny*0.75)]
# Out:
# 90.0

# %%
fig3 = plt.figure(constrained_layout=True)
gs = fig3.add_gridspec(2, 5)
ax = fig3.add_subplot(gs[0, 0:2])


ax.plot(range(nt),Q[0,int(ny*0.75),:],'k' )
ax.set(xlabel='Time [Months]',ylabel='Heatflux [W/m$^2$]')
ax.minorticks_on()

#ax.grid(which='minor',linestyle='--', alpha=0.5,)
ax.grid(which='major',alpha=0.7)

ax.text(0, 1.02, '(a)', fontweight='bold', color='k', 
        transform=ax.transAxes)

ax = fig3.add_subplot(gs[1, 0:2])

ax.plot(tempBo[0,:,0],-z )
ax.set(xlabel='Temperature [°C]',ylabel='Depth [m]')
ax.text(0, 1.02, '(b)', fontweight='bold', color='k', 
        transform=ax.transAxes)


ax = fig3.add_subplot(gs[:, 2])

colors=cmocean.cm.solar(np.linspace(0, 1, 3))
cax=ax.pcolormesh(Q[:,:,6].T,cmap=cmocean.cm.solar)

cbar= plt.colorbar(cax)
cbar.set_label('Heatflux [W/m$^2$]')
ax.set(xlabel='Distance [km]',ylabel='Distance [km]')
ax.set_facecolor(colors[-3])

#plt.gca().set_aspect('equal')




ax.axhline(y[20]*2,linestyle='dashed',c='brown',linewidth=1)
ax.text(0,(y[20]+2)*2, 'Sponge\nend', va='center',color='brown',fontsize='small')

ax.axhline(y[-20]*2,linestyle='dashed',c='brown',linewidth=1)
ax.text(0,(y[-20]+2)*2, 'Sponge\nend', va='center',color='brown',fontsize='small')
ax.axhline(y[int(ny*0.75)]*2,c='k')

ax.text(-0.3, 1.02, '(b)', fontweight='bold', color='k', 
        transform=ax.transAxes)

ax = fig3.add_subplot(gs[:, 4])

colors=cmocean.cm.deep(np.linspace(0, 1, 3))

cax=ax.pcolormesh(-ho.T,cmap=cmocean.cm.deep)

ax.axhline(y[20]*2,linestyle='dashed',c='white',linewidth=1)
ax.text(0,(y[20]+2)*2, 'Sponge\nend', va='center',color='white',fontsize='small')

ax.axhline(y[-20]*2,linestyle='dashed',c='white',linewidth=1)
ax.text(0,(y[-20]+2)*2, 'Sponge\nend', va='center',color='white',fontsize='small')


cbar= plt.colorbar(cax)
cbar.set_label('Depth [m]')
ax.set(xlabel='Distance [km]')
ax.yaxis.set_tick_params(labelleft=False)
ax.set_facecolor(colors[0])
ax.text(0, 1.02, '(c)', fontweight='bold', color='k', 
        transform=ax.transAxes)

#ax = fig3.add_subplot(gs[:, 4])

#cax=ax.pcolormesh(x,y,T_mask[0,:,:].T)
#ax.axis('equal')
#cbar= plt.colorbar(cax)
#cbar.set_label('Restoring temperature area ')
#ax.set(xlabel='Distance [km]')
#ax.yaxis.set_tick_params(labelleft=False)


#plt.savefig(str(location)+'/Figures/InputVars.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 18
#      13 ax.text(0, 1.02, '(a)', fontweight='bold', color='k',
#      14         transform=ax.transAxes)
#      16 ax = fig3.add_subplot(gs[1, 0:2])
# ---> 18 ax.plot(tempBo[0,:,0],-z )
#      19 ax.set(xlabel='Temperature [°C]',ylabel='Depth [m]')
#      20 ax.text(0, 1.02, '(b)', fontweight='bold', color='k',
#      21         transform=ax.transAxes)
#
# NameError: name 'tempBo' is not defined

# %% [markdown]
# # High Res

# %%
import numpy as np
import array
import sys
import matplotlib.pyplot as plt
from math import sin
import pylab as pl

sponge='True'

project='highRes'
location='/HOME/users/amelia.th/Model/IntercambioNGC/'
run='/run2/'
def write_with_byte_inversion(f, tab):
    tab2write = array.array('f', tab.T.flatten())
    if sys.byteorder == 'little':
        tab2write.byteswap()
    f.write(tab2write)

dtype=np.float32

Ho=1280  # ocean depth in meters
nx=1    # number of gridpoints in x-direction
ny=240    # number of total gridpoints in y-direction
nyA=210    # number of active gridpoints in y-direction
nyS=20    # number of longer dy gridpoints in y-direction
nySend=10
nz=160     # number of gridpoints in z-direction
nt=12 #nt=10  #for 3 years with timestep 60 s

dx=1
dz=8

inc=0.12
ninc=30
start=1 + inc
maxi=ninc*inc+start
dy=1000*np.append(np.ones(nyS)*maxi,np.append(np.arange(maxi,start,-inc),np.append(np.ones(ny-nyS-ninc*2),np.arange(start,maxi,inc))))
y=np.cumsum(dy)/1000

x=np.arange(0,nx*dx,dx)
z=np.arange(0,nz*dz,dz)

umbral=ny*0.4

lat=(22.92+31.70)/2

omega=7.2921*(10**(-5))

f=2*omega*sin(np.deg2rad(lat))

def gaussian(x, mu, sig):
    return (
         np.exp(-np.power((x - mu) / sig, 2.0) / 2)
    )

#Bathymetry definition
dep=(gaussian(np.arange(ny), umbral, 10)*800-Ho)
ho[:,:]=np.tile(dep,(nx,1))
ho[:,-1]=0


#Values of temperature at open boundary
tempBo=15*np.ones((nx,nz,nt),dtype=dtype)

#Values of salinity at open boundary
salBo=np.zeros((nx,nz,nt),dtype=dtype)

#Defining heatflux
out=gaussian(y, 0.8*y[-1], 10)
Q=np.zeros((nx,ny,nt), dtype=dtype)
for i in range(12):
    Q[:,:,i]=-1000*out*(gaussian(np.arange(12), 5.5, 2)-np.min(gaussian(np.arange(12), 5.5, 2)))[11-i]


temp=15*np.ones((nx,ny,nz),dtype=dtype)
temp[:,int(umbral):,:]=temp[:,int(umbral):,:]+1

# %%
y[int(umbral)]
# Out:
# 230.8

# %%
plt.plot(y,dy)

# %%
fig,ax=plt.subplots()
ax.plot(y,ho[0,:])
ax2=ax.twinx()
ax2.plot(y,temp[0,:,0])

# %%
#### Plotting #####

params = {'font.size': 8,
          'figure.figsize': (8, 6),
         'font.family':'sans'}
pl.rcParams.update(params)

fig3 = plt.figure()
gs = fig3.add_gridspec(2, 3)
ax = fig3.add_subplot(gs[0, 0:2])
ax.set(ylabel='Horizontal resoluton in y [km]',xlabel='Distance in y [km]')

ax1=ax.twinx()
ax1.plot(y,ho[0],color='tab:brown',label='Depth [m]')
ax1.plot(y,Q[0,:,6],color='tab:orange',label='Heatflux [Wm$^{-2}$]')
ax1.set(ylabel='Depth [m]/Heatflux [Wm$^{-2}$]')

ax.plot(y,dy,'k',linestyle='dashed',linewidth=3,label=f'Horizontal resoluton in y [km] Max dy= {np.max(dy)} km')

fig3.legend(bbox_to_anchor=[0.6, 1.05],ncol=2)
ax.minorticks_on()

if sponge=='True':
        ax.axvline(y[nyS],linestyle='dashed',c='brown',linewidth=1)
        ax.text(y[nyS]+10,1500, 'Sponge\nend', va='center',color='brown',fontsize='small')


ax.grid(which='major',alpha=0.7)
ax.grid(which='minor',alpha=0.3)

ax.text(0, 1.02, '(a)', fontweight='bold', color='k',
        transform=ax.transAxes)

ax = fig3.add_subplot(gs[1, 0:2])

ax.plot(tempBo[0,:,0],-z )
ax.set(xlabel='Temperature [°C]',ylabel='Depth [m]')
ax.text(0, 1.02, '(b)', fontweight='bold', color='k',
        transform=ax.transAxes)


ax = fig3.add_subplot(gs[:, 2])

cax=ax.pcolormesh(y,range(nt),Q[0,:,:].T)
ax.text(y[-1]+100,11,f'Average over active basin:\n{np.sum(np.mean(np.mean(Q[:,nyS:,:],axis=0),axis=1))/len(np.arange(y[nyS],y[-1],1)):.3} W/m$^2$')
cbar= plt.colorbar(cax)
cbar.set_label('Heatflux [W/m$^2$]')
ax.set(xlabel='Distance [km]',ylabel='Time [Months]')
if sponge=='True':
        ax.axvline(y[nyS],linestyle='dashed',c='brown',linewidth=1)
        ax.text(y[nyS]+2,2, 'Sponge\nend', va='center',color='brown',fontsize='small')
        #ax.axvline(y[-nyS],linestyle='dashed',c='black',linewidth=1)
        #ax.text(y[-nyS]+2,2, 'High res\nend', va='center',color='black',fontsize='small')

ax.text(-0.3, 1.02, '(c)', fontweight='bold', color='k',
        transform=ax.transAxes)


plt.tight_layout()

# %% [markdown]
# # 3D sill

# %%
import numpy as np
import array
import sys
import matplotlib.pyplot as plt
from math import sin
import pylab as pl

sponge='True'

project='highRes'
location='/HOME/users/amelia.th/Model/IntercambioNGC/'
run='/run11/'
def write_with_byte_inversion(f, tab):
    tab2write = array.array('f', tab.T.flatten())
    if sys.byteorder == 'little':
        tab2write.byteswap()
    f.write(tab2write)

dtype=np.float32

Ho=1280  # ocean depth in meters
nx=20    # number of gridpoints in x-direction
ny=240    # number of total gridpoints in y-direction
nyS=20

nz=160     # number of gridpoints in z-direction
nt=12 #nt=10  #for 3 years with timestep 60 s

dx=1
dz=8

inc=0.05
ninc=30
start=1 + inc
maxi=ninc*inc+start
dy=1000*np.append(np.ones(nyS)*maxi,np.append(np.arange(maxi,start,-inc),np.append(np.ones(ny-nyS-ninc*2),np.arange(start,maxi,inc))))

y=np.cumsum(dy)/1000
x=np.arange(0,nx*dx,dx)
z=np.arange(0,nz*dz,dz)

umbral=ny*0.4
lat=(22.92+31.70)/2

omega=7.2921*(10**(-5))

f=2*omega*sin(np.deg2rad(lat))

def gaussian(x, mu, sig):
    return (
         np.exp(-np.power((x - mu) / sig, 2.0) / 2)
    )

# %%
#Defining heatflux
out=gaussian(y, 0.8*y[-1], 10)
Q=np.zeros((nx,ny,nt), dtype=dtype)
for i in range(12):
    Q[:,:,i]=-750*out*(gaussian(np.arange(12), 5.5, 2)-np.min(gaussian(np.arange(12), 5.5, 2)))[11-i]

temp=15*np.ones((nx,ny,nz),dtype=dtype)
temp[:,:int(umbral),60:]=temp[:,:int(umbral),60:]-1

#Q created to make the plot something
#Q=np.zeros((nx,ny,nt),dtype=dtype)

#Values of temperature at open boundary
tempBo=14*np.ones((nx,nz,nt),dtype=dtype)

#Values of salinity at open boundary
salBo=np.zeros((nx,nz,nt),dtype=dtype)

#Bathymetry definition
dep=(gaussian(np.arange(ny), umbral, 10)*800-Ho)
ho=np.tile(dep,(nx,1))
ho[:,-1]=0

# %%
plt.pcolormesh(y,x,Q[:,:,6])

# %%
#### Plotting #####

params = {'font.size': 8,
          'figure.figsize': (8, 6),
         'font.family':'sans'}
pl.rcParams.update(params)

fig3 = plt.figure()
gs = fig3.add_gridspec(2, 4)
ax = fig3.add_subplot(gs[0, 0:2])

ax.plot(y,Q[0,:,6],'k',label='Heatflux [W/m$^2$]')
ax2=ax.twinx()
ax2.plot(y,ho[0,:],'red',label='Depth [m]')
ax3=ax.twinx()
ax3.plot(y,dy,'k',linestyle='dashed',label='Resolution [m]')
ax.set(xlabel='Distance [km]',ylabel='Heatflux [W/m$^2$]')
ax.minorticks_on()
ax.text(0, 0.9, f'Mean heatflux {np.mean(Q[:,nyS:,:]):.1f} W/m$^2$', color='k',
        transform=ax.transAxes)

fig3.legend(bbox_to_anchor=[0.6, 1.05],ncol=2)

if sponge=='True':
        ax.axvline(y[20],linestyle='dashed',c='brown',linewidth=1)
        ax.text(y[20]+10,-600, 'Sponge\nend', va='center',color='brown',fontsize='small')


ax.grid(which='major',alpha=0.7)

ax.text(0, 1.02, '(a)', fontweight='bold', color='k',
        transform=ax.transAxes)

ax = fig3.add_subplot(gs[1, 0:2])

caxT=ax.pcolormesh(y,-z,temp[0,:,:].T)
ax.plot(y,ho[0,:])
ax.set(xlabel='Distance [km]',ylabel='Depth [m]')

cbar= plt.colorbar(caxT)
cbar.set_label('Temperature south of the sill [°C]')

ax.text(0, 1.02, '(b)', fontweight='bold', color='k',
        transform=ax.transAxes)

ax = fig3.add_subplot(gs[:, 2])

cax=ax.pcolormesh(np.arange(nt),y,Q[0,:,:])

cbar= plt.colorbar(cax)
cbar.set_label('Heatflux [W/m$^2$]')
ax.set(xlabel='Time [months]',ylabel='Distance [km]')
#if sponge=='True':
#	ax.axvline(y[20],linestyle='dashed',c='brown',linewidth=1)
#	ax.text(y[20]+2,2, 'Sponge\nend', va='center',color='brown',fontsize='small')

ax.text(-0.3, 1.02, '(c)', fontweight='bold', color='k',
        transform=ax.transAxes)

ax = fig3.add_subplot(gs[:, 3])

cax=ax.pcolormesh(x,y,-ho.T)

#if sponge=='True':
#	ax.axhline(y[20],linestyle='dashed',c='white',linewidth=1)
#	ax.text(0,y[20]+10, 'Sponge\nend', va='center',color='white',fontsize='small')


cbar= plt.colorbar(cax)
cbar.set_label('Depth [m]')
ax.set(ylabel='Distance [km]',xlabel='Distance [km]')
ax.text(0, 1.02, '(d)', fontweight='bold', color='k',
        transform=ax.transAxes)

plt.tight_layout()
#plt.savefig(str(location)+str(project)+'/Figures'+str(run)+'InputVars.png',dpi=400,bbox_inches='tight')
#plt.show()

# %%
import numpy as np
import array
import sys
import matplotlib.pyplot as plt
from math import sin
import pylab as pl

spongeN='True'

project='OpenNorth'
location='/HOME/users/amelia.th/Model/IntercambioNGC/'
run='/run1/'
def write_with_byte_inversion(f, tab):
    tab2write = array.array('f', tab.T.flatten())
    if sys.byteorder == 'little':
        tab2write.byteswap()
    f.write(tab2write)

dtype=np.float32

Ho=1280  # ocean depth in meters
nx=10    # number of gridpoints in x-direction
ny=120    # number of total gridpoints in y-direction
nyS=10

nz=80     # number of gridpoints in z-direction
nt=12 #nt=10  #for 3 years with timestep 60 s

dx=2
dz=16
dy=2

y=np.arange(0,ny*dy,dy)
x=np.arange(0,nx*dx,dx)
z=np.arange(0,nz*dz,dz)

umbral=ny*0.4
lat=(22.92+31.70)/2

omega=7.2921*(10**(-5))

f=2*omega*sin(np.deg2rad(lat))

# %%
def gaussian(x, mu, sig):
    return (
         np.exp(-np.power((x - mu) / sig, 2.0) / 2)
    )

# %%
#Bathymetry definition
dep=(gaussian(y,y[int(umbral)], 10)*800-Ho)
ho=np.tile(dep,(nx,1))
ho[0,:]=0
ho[-1,:]=0

# %%
sponge='False'

# %%
indzSill=len(z[z<-np.max(ho[ho!=0])])
tempN=np.zeros(nz)
tempN[:indzSill]=np.arange(15,13,(13-15)/indzSill)
tempN[indzSill-1:]=np.arange(tempN[indzSill-1],11,(11-tempN[indzSill-1])/(nz-indzSill+1))

indz600=len(z[z<600])
tempS=np.zeros(nz)
tempS[:indz600]=np.arange(16,7,(7-16)/indz600)
tempS[indz600-1:]=np.arange(tempS[indz600-1],5,(5-tempS[indz600-1])/(nz-indz600+1))

# %%
plt.plot(tempN,-z)
plt.plot(tempS,-z)

# %%
#Values of salinity at open boundary
salBo=np.zeros((nx,nz,nt),dtype=dtype)

#Bathymetry definition
dep=(gaussian(y,y[int(umbral)], 10)*800-Ho)
ho=np.tile(dep,(nx,1))
ho[0,:]=0
ho[-1,:]=0

#Values of temperature at open boundary NORTH
indzSill=len(z[z<-np.max(ho[ho!=0])])
tempN=np.zeros(nz)
tempN[:indzSill]=np.arange(15,13,(13-15)/indzSill)
tempN[indzSill-1:]=np.arange(tempN[indzSill-1],11,(11-tempN[indzSill-1])/(nz-indzSill+1))
tempBoN=np.tile(np.tile(tempN,(nx,1)).T,(nt,1,1)).T

#Values of temperature at open boundary SOUTH
indz600=len(z[z<600])
tempS=np.zeros(nz)
tempS[:indz600]=np.arange(16,7,(7-16)/indz600)
tempS[indz600-1:]=np.arange(tempS[indz600-1],5,(5-tempS[indz600-1])/(nz-indz600+1))
tempBoS=np.tile(np.tile(tempS,(nx,1)).T,(nt,1,1)).T

#### Plotting #####

params = {'font.size': 8,
          'figure.figsize': (8, 6),
         'font.family':'sans'}
pl.rcParams.update(params)

fig3 = plt.figure()
gs = fig3.add_gridspec(2, 3)
ax = fig3.add_subplot(gs[0, 0:2])

ax.plot(y,ho[1,:],'green',label='Depth [m]')

ax1=ax.twiny()
ax1.plot(tempN,-z,'blue',label='Northern boundary')
ax1.plot(tempS,-z,'red',label='Southern boundary')
ax1.set(xlabel='Temperature [degC]')

ax.set(xlabel='Distance [km]',ylabel='Depth [m]')
ax.minorticks_on()

fig3.legend(bbox_to_anchor=[0.6, 0.65])

if sponge=='True':
        ax.axvline(y[nyS],linestyle='dashed',c='brown',linewidth=1)
        ax.text(y[nyS]+5,-200, 'Sponge\nend', va='center',color='brown',fontsize='small')
elif spongeN=='True':
        ax.axvline(y[nyS],linestyle='dashed',c='brown',linewidth=1)
        ax.text(y[nyS]+5,-200, 'Sponge\nend', va='center',color='brown',fontsize='small')
        ax.axvline(y[-nyS],linestyle='dashed',c='brown',linewidth=1)
        ax.text(y[-nyS]+5,-200, 'Sponge\nend', va='center',color='brown',fontsize='small')

ax.grid(which='major',alpha=0.7)

ax.text(0, 1.02, '(a)', fontweight='bold', color='k', 
        transform=ax.transAxes)

ax = fig3.add_subplot(gs[1, 0])

caxT=ax.pcolormesh(x,-z,tempBoN[:,:,0].T)
ax.set(xlabel='Distance [km]',ylabel='Depth [m]')
ax.text(0, 1.02, '(b)', fontweight='bold', color='k', 
        transform=ax.transAxes)

cbar= plt.colorbar(caxT)
cbar.set_label('Temperature Northern Boundary [°C]')

ax = fig3.add_subplot(gs[1, 1])

caxT=ax.pcolormesh(x,-z,tempBoS[:,:,0].T)
ax.set(xlabel='Distance [km]',ylabel='Depth [m]')
ax.text(0, 1.02, '(c)', fontweight='bold', color='k', 
        transform=ax.transAxes)

cbar= plt.colorbar(caxT)
cbar.set_label('Temperature southern Boundary[°C]')

ax = fig3.add_subplot(gs[:, 2])

cax=ax.pcolormesh(x,y,-ho.T)

cbar= plt.colorbar(cax)
cbar.set_label('Depth [m]')
ax.set(ylabel='Distance [km]',xlabel='Distance [km]')
ax.text(0, 1.02, '(d)', fontweight='bold', color='k', 
        transform=ax.transAxes)

plt.tight_layout()
#plt.savefig(str(location)+str(project)+'/Figures'+str(run)+'InputVars.png',dpi=400,bbox_inches='tight')
plt.show()

# %% [markdown]
# # Save the file

# %%
f = open('../' + str(project) + '/input/Qnet.bin','wb')
write_with_byte_inversion(f, Q)
f.close()

# %%
f = open('../' + str(project) + '/input/bathy.bin','wb')
write_with_byte_inversion(f, ho)
f.close()

# %%
f = open('../' + str(project) + '/input/tempOBCS.bin','wb')
write_with_byte_inversion(f, tempBo)
f.close()

# %%
f = open('../' + str(project) + '/input/T_relax_mask.bin','wb')
write_with_byte_inversion(f, T_mask)
f.close()

# %%
f = open('../' + str(project) + '/input/temperature.bin','wb')
write_with_byte_inversion(f, tempRelax)
f.close()
