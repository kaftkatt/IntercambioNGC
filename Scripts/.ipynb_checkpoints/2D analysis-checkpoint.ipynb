# %%
from xmitgcm import open_mdsdataset
import xmitgcm 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import xarray as xr
import cmocean
import pylab as pl
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation
import ffmpeg
from matplotlib import animation
from matplotlib.gridspec import GridSpec

from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

import MITgcmutils
import math
import netCDF4 as nc
from scipy.io import savemat
import scipy as sc
import scipy.io as sio
import scipy.interpolate as sciint
import warnings
import datetime
warnings.filterwarnings("ignore")

# %%
params = {'font.size': 10,
          'figure.figsize': (8, 4),
         'font.family':'sans'}
pl.rcParams.update(params)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
fig,ax=plt.subplots()

ax.plot(ds.T.values/(60*60*24*360),np.mean(np.mean(ds.THETA[:,:zind,OB:OBend,0],axis=1),axis=1))

ax.set(xlabel='Time (Years)',ylabel='Temperature (°C)',title='Mean Over The Whole Basin')

ax.text(0, 1.05, '(a)', fontweight='bold', color='k', 
        transform=ax.transAxes)

fig.tight_layout()
plt.savefig('../' + str(project)+'/Figures/' +str(ed)+ 'OBCStest.png', bbox_inches='tight')

# %%
params = {'font.size': 10,
          'figure.figsize': (8, 8),
         'font.family':'sans'}
pl.rcParams.update(params)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
fig,axin=plt.subplots(2)

ax=axin[0]
xlab= 'SSH [m]'#'Meridional Transport of Density (kg/m$^2$/s)'
inarr=dsS.ETAN[:,:,:,:].values

ax.plot(dsS.Y[OB:OBend]/1000,np.mean(inarr[tin:,0,OB:OBend,0],axis=0), linewidth=3,c='k')
ax.set(xlabel='Distance in Y [km]',ylabel=xlab)
ax.minorticks_on()

ax.grid(which='minor',linestyle='--', alpha=0.5)
ax.grid(which='major',alpha=0.7)


#pressure
g=10
rho0=1000
inarr=(np.mean((rho0*np.sum(-g*dsG.Z.values[None,:zind,None] + ds.PHIHYD.values[tin:,:zind,OB:OBend,0],axis=1)),axis=0)+g*rho0*np.mean(dsS.ETAN.values[tinS:,0,OB:OBend,0],axis=0))/(len(dsG.Z[:zind])+1)


ax=axin[1]
xlab= 'Hydrostatic Pressure [Pa]'


ax.plot(dsG.Y[OB:OBend]/1000,inarr, linewidth=2,color='k',label='Total')

ax.set(xlabel='Distance in Y [km]',ylabel=xlab)
ax.minorticks_on()

ax.grid(which='minor',linestyle='--', alpha=0.5)
ax.grid(which='major',alpha=0.7)

fig.tight_layout()
plt.savefig('../' + str(project)+'/Figures/' +str(ed)+ 'Pressure.png', bbox_inches='tight')

# %%
params = {'font.size': 10,
          'figure.figsize': (8, 8),
         'font.family':'sans'}
pl.rcParams.update(params)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
tin=0

# %%
space=8
spacex=2

varin=ds.THETA
Yin=dsG.Y[OBp:OBendp]
Xin=dsG.X
Zin=dsG.Z
vmin=np.min(np.ma.masked_array(np.mean(varin[tin:,:,OB:OBend,0],axis=0),mask=mask[:,OB:OBend,0]))
vmax=np.max(np.ma.masked_array(np.mean(varin[tin:,:,OB:OBend,0],axis=0),mask=mask[:,OB:OBend,0]))
cmapi=cmocean.cm.thermal

levels=np.linspace(vmin,vmax,15)

fig = plt.figure()
gs = GridSpec(nrows=4, ncols=1)

axin = fig.add_subplot(gs[0, 0])
axin.set(xlabel='Distance in y [km]')
axin.set(ylabel='Depth [m]')

timein=ds.T[tin]/(60*60*24)
cax0=axin.pcolormesh(Yin/1000, Zin, np.ma.masked_array(np.mean(varin[tin:,:,OBp:OBendp,0],axis=0),mask=mask[:,OBp:OBendp,0]),vmin=vmin,vmax=vmax,cmap=cmapi)

cbar_ax = plt.colorbar(cax0)
cbar_ax.set_label('Temperature [degC]')
for i in np.arange(0.2,1,0.15):
    axin.axvline(ds.Y[int(i*ny)]/1000,c='k',alpha=i)

axin.text(0, 1.05, '(a)', fontweight='bold', color='k', 
        transform=axin.transAxes)
axin.axvline(ds.Y[20]/1000,c='white',linestyle='dashed')
axin.text(0.09, 0.05, 'End of \nSponge', color='white', 
        transform=axin.transAxes,fontsize=8)

axin = fig.add_subplot(gs[1, 0])

gridZ,gridY=np.meshgrid(dsG.Z.values,dsG.Y.values)

interpV=sciint.RegularGridInterpolator((dsG.Z.values,dsG.Yp1.values),np.mean(ds.VVEL[tin:,:,:,0].values,axis=0))
V=interpV((gridZ,gridY))

title= ds.VVEL.description 
Yin=ds.Y[OBp:OBendp]
Xin=ds.X
vmin=np.min(np.ma.masked_array(V[OB:OBend,:].T*100,mask=mask[:,OB:OBend,0]))
vmax=-np.min(np.ma.masked_array(V[OB:OBend,:].T*100,mask=mask[:,OB:OBend,0]))
cmapi=cmocean.cm.balance

levels=np.linspace(vmin,vmax,15)

axin.set(xlabel='Distance in y [km]')
axin.set(ylabel='Depth [m]')

timein=ds.T[-tin]/(60*60*24)
cax0=axin.pcolormesh(Yin/1000, Zin, np.ma.masked_array(V[OBp:OBendp,:].T*100,mask=mask[:,OBp:OBendp,0]),vmin=vmin,vmax=vmax,cmap=cmapi)

cbar_ax = plt.colorbar(cax0)
axin.axvline(ds.Y[int(0.75*ny)]/1000,c='k')
cbar_ax.set_label('Meridional\n velocity [cm/s]')


varin=ds.UVEL
title= varin.description 
Yin=ds.Y[OBp:OBendp]
Xin=ds.Xp1
vmin=np.min(np.ma.masked_array(np.mean(np.mean(varin[tin:,:,OB:OBend,:],axis=0),axis=2))*100)
vmax=-np.min(np.ma.masked_array(np.mean(np.mean(varin[tin:,:,OB:OBend,:],axis=0),axis=2))*100)
cmapi=cmocean.cm.balance

levels=np.linspace(vmin,vmax,15)

axin.text(0, 1.05, '(b)', fontweight='bold', color='k', 
        transform=axin.transAxes)

axin.axvline(ds.Y[20]/1000,c='k',linestyle='dashed')
axin.text(0.09, 0.05, 'End of \nSponge', color='k', 
        transform=axin.transAxes,fontsize=8)

axin = fig.add_subplot(gs[2, 0])

axin.set(xlabel='Distance in y [km]')
axin.set(ylabel='Depth [m]')

timein=ds.T[-tin]/(60*60*24)
cax0=axin.pcolormesh(Yin/1000, Zin, np.ma.masked_array(np.mean(np.mean(varin[tin:,:,OBp:OBendp,:],axis=0),axis=2)*100,mask=maskw[:,OBp:OBendp,0]),vmin=vmin,vmax=vmax,cmap=cmapi)

cbar_ax = plt.colorbar(cax0)
cbar_ax.set_label('Zonal velocity [cm/s]')

axin.axvline(ds.Y[int(0.75*ny)]/1000,c='k')
axin.text(0, 1.05, '(c)', fontweight='bold', color='k', 
        transform=axin.transAxes)
axin.axvline(ds.Y[20]/1000,c='k',linestyle='dashed')
axin.text(0.09, 0.05, 'End of \nSponge', color='k', 
        transform=axin.transAxes,fontsize=8)


gridZ,gridY=np.meshgrid(dsG.Z[1:].values,dsG.Y.values)

interpV=sciint.RegularGridInterpolator((dsG.Zu.values,dsG.Y.values),np.mean(ds.WVEL[tin:,:,:,0].values,axis=0))
varin=interpV((gridZ,gridY))

title= ds.WVEL.description 
Yin=dsG.Y[OBp:OBendp]
Xin=ds.X
Zin=dsG.Z
vmin=np.min(np.ma.masked_array(varin[OB:OBend,:].T*100,mask=mask[1:,OB:OBend,0]))
vmax=-np.min(np.ma.masked_array(varin[OB:OBend,:].T*100,mask=mask[1:,OB:OBend,0]))
cmapi=cmocean.cm.balance
levels=np.linspace(vmin,vmax,15)

axin = fig.add_subplot(gs[3, 0])

axin.set(xlabel='Distance in y [km]')
axin.set(ylabel='Depth [m]')

timein=ds.T[-tin]/(60*60*24)
cax1=axin.pcolormesh(Yin/1000, Zin[1:], np.ma.masked_array(varin[OBp:OBendp,:].T*100,mask=mask[1:,OBp:OBendp,0]),vmin=vmin,vmax=vmax,cmap=cmapi)

cbar_ax = plt.colorbar(cax1)
cbar_ax.set_label('Vertical velocity [cm/s]')

axin.axvline(ds.Y[int(0.75*ny)]/1000,c='k')

axin.axvline(ds.Y[int(0.5*ny)]/1000,c='k')

axin.axvline(ds.Y[20]/1000,c='k',linestyle='dashed')
axin.text(0.09, 0.05, 'End of \nSponge', color='k', 
        transform=axin.transAxes,fontsize=8)

axin.text(0, 1.05, '(d)', fontweight='bold', color='k', 
        transform=axin.transAxes)

fig.tight_layout()

plt.savefig('../' + str(project)+'/Figures/' +str(ed)+ 'crossectionsMean.png', bbox_inches='tight')

# %% [markdown]
# ##### Check heatflux
# ## yes
# ##### Change relaxation time scale
# ## tried to lower it
# ##### Change diffusivity
# ##### Change resolution in the horizontal
# ##### Change resolution in the vertical

# %%
params = {'font.size': 10,
          'figure.figsize': (8, 8),
         'font.family':'sans'}
pl.rcParams.update(params)
plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 200

# %%
fig,axin=plt.subplots(1,2)
ax=axin[0]
ax.plot(np.ma.masked_array(V[int(0.5*ny),:]*100,mask=masks[:,int(0.5*ny),0]),dsG.Z,color='k',linewidth=1.5,label=f'Sum of Line: {np.sum(np.ma.masked_array(V[int(0.5*ny),:]*100,mask=masks[:,int(0.5*ny),0])):.2e}')
ax.set(xlabel='Meridional Velocity [cm/s]',ylabel='Depth [m]')
ax.axvline(0,linewidth=1, color='r')
ax.minorticks_on()

ax.grid(which='minor',linestyle='--', alpha=0.5)
ax.grid(which='major',alpha=0.7)
ax.legend()

ax=axin[1]
varin=ds.THETA
sub_ax = ax.inset_axes([0.5, 0.1, 0.7, 0.47]) #[x0, y0, width, height] 
subsub_ax = sub_ax.inset_axes([0.4, 0.1, 0.8, 0.47]) #[x0, y0, width, height] 
for i in np.arange(0.2,1,0.15):
    if np.logical_and(i<=0.5,i>0.4):
        ax.plot(np.ma.masked_array(np.mean(varin[tin:,:,int(i*ny),0],axis=0),mask=mask[:,int(i*ny),0]),dsG.Z,color='k',linewidth=1.5,alpha=i,linestyle='dashed',label='On sill')
    else:  
        ax.plot(np.ma.masked_array(np.mean(varin[tin:,:,int(i*ny),0],axis=0),mask=mask[:,int(i*ny),0]),dsG.Z,color='k',linewidth=1.5,alpha=i)
        sub_ax.plot(np.ma.masked_array(np.mean(varin[tin:,:,int(i*ny),0],axis=0),mask=mask[:,int(i*ny),0])[dsG.Z<-600],dsG.Z[dsG.Z<-600],alpha=i,color='k')
        subsub_ax.plot(np.ma.masked_array(np.mean(varin[tin:,:,int(i*ny),0],axis=0),mask=mask[:,int(i*ny),0])[dsG.Z<-800],dsG.Z[dsG.Z<-800],alpha=i,color='k')

ax.set(xlabel='Potential Temperature [°C]',ylabel='Depth [m]')

ax.legend()

ax.minorticks_on()

ax.grid(which='minor',linestyle='--', alpha=0.5)
ax.grid(which='major',alpha=0.7)

sub_ax.minorticks_on()

sub_ax.grid(which='minor',linestyle='--', alpha=0.5)
sub_ax.grid(which='major',alpha=0.7)

subsub_ax.minorticks_on()

subsub_ax.grid(which='minor',linestyle='--', alpha=0.5)
subsub_ax.grid(which='major',alpha=0.7)

fig.tight_layout()

plt.savefig('../' + str(project)+'/Figures/' +str(ed)+ 'VelocityMean.png', bbox_inches='tight')

# %% [markdown]
# ## Comparison plots

# %%
project='shortTime'
ed='run1/'
if ed == 'run15/':
    drag = '1e-3'
elif ed == 'run16/':
    drag = '0'
elif ed == 'run17/':
    drag = '1e-2'
elif ed == 'run18/':
    drag ='1e-4'

location='/Users/ameliaking/Proyecto/Codigo/NGC/'+ str(project) + '/Files/' + str(ed) #'/Users/ameliaking/Proyecto/Codigo/Idealizada/ChangeDim/'

#location='/home/amelia/NGC/'+ str(project) + '/Files/' + str(ed) #'/Users/ameliaking/Proyecto/Codigo/Idealizada/ChangeDim/'

var='dynDiag'

ds=xr.open_dataset(str(location) +  str(var) + '.nc')


varS='surfDiag'

dsS=xr.open_dataset(str(location) +  str(varS) + '.nc')

varG='grid'

dsG=xr.open_dataset(str(location) +  str(varG) + '.nc')

#Take them minus 1 and 2 to skip the boundary
ny=len(ds.Y)
nx=len(ds.X) 
nz=len(ds.diag_levels)

hFacC = dsG.HFacC

hfa = np.ma.masked_values(hFacC, 0)
mask = np.ma.getmask(hfa)

hFacW = dsG.HFacW

hfaW = np.ma.masked_values(hFacW, 0)
maskw = np.ma.getmask(hfaW)

hFacS = dsG.HFacS

hfaS = np.ma.masked_values(hFacS, 0)
masks = np.ma.getmask(hfaS)

if project == '2Dsill':
    OB=1
    OBend=-1
elif project =='2DsillOB':
    OBp=1
    OBendp=-1
    OB=21
    OBend=-1

# %%
project='shortTime'
edc='run2/'
if edc == 'run15/':
    dragc='1e-3'
elif edc == 'run16/':
    dragc='0'
elif edc == 'run17/':
    dragc='1e-2'
elif edc == 'run18/':
    dragc='1e-4'
elif edc == 'run19/':
    dragc='0DifDif'
location='/Users/ameliaking/Proyecto/Codigo/NGC/'+ str(project) + '/Files/' + str(edc) #'/Users/ameliaking/Proyecto/Codigo/Idealizada/ChangeDim/'


var='dynDiag'

dsc=xr.open_dataset(str(location) +  str(var) + '.nc')


varS='surfDiag'

dsSc=xr.open_dataset(str(location) +  str(varS) + '.nc')

varG='grid'

dsGc=xr.open_dataset(str(location) +  str(varG) + '.nc')

#Take them minus 1 and 2 to skip the boundary
nyc=len(dsc.Y)
nxc=len(dsc.X) 
nzc=len(dsc.diag_levels)

hFacCc = dsGc.HFacC

hfac = np.ma.masked_values(hFacCc, 0)
maskc = np.ma.getmask(hfac)

hFacWc = dsGc.HFacW

hfaWc = np.ma.masked_values(hFacWc, 0)
maskwc = np.ma.getmask(hfaWc)

hFacSc = dsGc.HFacS

hfaSc = np.ma.masked_values(hFacSc, 0)
masksc = np.ma.getmask(hfaSc)

tinc=np.where(dsc.T/(24*60*60*360)>9.6)[0][0]
tinSc=np.where(dsSc.T/(24*60*60*360)>9.6)[0][0]

# %%
tin=np.where(ds.T/(24*60*60*360)>9.6)[0][0]
tinS=np.where(dsS.T/(24*60*60*360)>9.6)[0][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 tin=np.where(ds.T/(24*60*60*360)>9.6)[0][0]
#       2 tinS=np.where(dsS.T/(24*60*60*360)>9.6)[0][0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
zind=np.where(dsG.Z>-400)[0][-1]

# %%
tinplot=30
## Crossections ##

params = {'figure.figsize': (8, 8),
         'font.family':'sans'}
pl.rcParams.update(params)

t=ds.T/(60*60*24)
varin=ds.THETA[:,ds.THETA[0,:,int(ny*0.5),0].values!=0,:,:]
title= 'Potential Temperature [°C]'
Yin=dsG.Y[OBp:OBendp]
Xin=dsG.X
Zin=dsG.Z[ds.THETA[0,:,int(ny*0.5),0].values!=0]
vmin=np.min(varin[tinplot:,:,int(ny*0.5),0])
vmax=np.max(varin[tinplot:,:,int(ny*0.5),0])
cmapi=cmocean.cm.thermal

levels=np.linspace(vmin,vmax,15)

fig = plt.figure()
gs = GridSpec(nrows=2, ncols=2)

axin = fig.add_subplot(gs[0, 0])
axin.set(xlabel='Time [days]')
axin.set(ylabel='Depth [m]')

timein=ds.T[tin]/(60*60*24)
cax0=axin.pcolormesh(t, Zin, varin[:,:,int(ny*0.5),0].T,vmin=vmin,vmax=vmax,cmap=cmapi)

cbar_ax = plt.colorbar(cax0)
cbar_ax.set_label('Temperature [degC]')

axin.text(0, 1.05, '(a)', fontweight='bold', color='k',
        transform=axin.transAxes)


axin = fig.add_subplot(gs[0, 1])

V=ds.VVEL[:,ds.VVEL[10,:,int(ny*0.5),0].values!=0,int(ny*0.5),0]

title= ds.VVEL.description
Yin=ds.Yp1[OBp:OBendp]
Xin=ds.X
vmin=np.min(V[tinplot:]*100)
vmax=-np.min(V[tinplot:]*100)
cmapi=cmocean.cm.balance

levels=np.linspace(vmin,vmax,15)

axin.set(xlabel='Time [days]')
axin.set(ylabel='Depth [m]')

timein=ds.T[-tin]/(60*60*24)
cax0=axin.pcolormesh(t, Zin, V.T*100,vmin=vmin,vmax=vmax,cmap=cmapi)

cbar_ax = plt.colorbar(cax0)

cbar_ax.set_label('Meridional\n velocity [cm/s]')

varin=np.mean(ds.UVEL[:,ds.UVEL[10,:,int(ny*0.5),0].values!=0,int(ny*0.5),:],axis=2)
title= ds.UVEL.description
Yin=ds.Y[OBp:OBendp]
Xin=ds.Xp1
vmin=np.min(varin[tinplot:]*100)
vmax=-np.min(varin[tinplot:]*100)
cmapi=cmocean.cm.balance

levels=np.linspace(vmin,vmax,15)

axin.text(0, 1.05, '(b)', fontweight='bold', color='k',
        transform=axin.transAxes)

axin = fig.add_subplot(gs[1, 0])

axin.set(xlabel='Time [days]')
axin.set(ylabel='Depth [m]')

cax0=axin.pcolormesh(t, Zin,varin.T*100,vmin=vmin,vmax=vmax,cmap=cmapi)
cbar_ax = plt.colorbar(cax0)
cbar_ax.set_label('Zonal velocity [cm/s]')


axin.text(0, 1.05, '(c)', fontweight='bold', color='k',
        transform=axin.transAxes)


varin=ds.WVEL[:,ds.WVEL[10,:,int(ny*0.5),0].values!=0,int(ny*0.5),0]

title= ds.WVEL.description

Yin=dsG.Y[OBp:OBendp]
Xin=ds.X

vmin=np.min(varin[tinplot:]*100)
vmax=-np.min(varin[tinplot:]*100)
cmapi=cmocean.cm.balance
levels=np.linspace(vmin,vmax,15)

axin = fig.add_subplot(gs[1, 1])
axin.set(xlabel='Time [days]')
axin.set(ylabel='Depth [m]')

timein=ds.T[-tin]/(60*60*24)
cax1=axin.pcolormesh(t, Zin,varin.T*100,vmin=vmin,vmax=vmax,cmap=cmapi)

cbar_ax = plt.colorbar(cax1)
cbar_ax.set_label('Vertical velocity [cm/s]')

axin.text(0, 1.05, '(d)', fontweight='bold', color='k',
        transform=axin.transAxes)

fig.tight_layout()


plt.savefig('../' + str(project)+'/Figures/hovmöller.png',dpi=400)

# %%
colors=[ '#4daf4a', '#a65628', '#984ea3',
                   '#e41a1c', '#dede00','#377eb8'
       ,'#ff7f00','#f781bf','#999999']

# %%
## Crossections ##

params = {'figure.figsize': (8, 8),
         'font.family':'sans'}
pl.rcParams.update(params)

varin=ds.THETA[tin].values-dsc.THETA[tinc].values
title= 'Potential Temperature [°C]'
Yin=dsG.Y[OBp:OBendp]
Xin=dsG.X
Zin=dsG.Z
vmin=np.min(np.ma.masked_array(varin[:,OB:OBend,0],mask=mask[:,OB:OBend,0]))
vmax=np.max(np.ma.masked_array(varin[:,OB:OBend,0],mask=mask[:,OB:OBend,0]))
cmapi=cmocean.cm.thermal

levels=np.linspace(vmin,vmax,15)

fig = plt.figure()
gs = GridSpec(nrows=4, ncols=1)

axin = fig.add_subplot(gs[0, 0])
axin.set(xlabel='Distance in y [km]')
axin.set(ylabel='Depth [m]')

timein=ds.T[tin]/(60*60*24)
cax0=axin.pcolormesh(Yin/1000, Zin, np.ma.masked_array(varin[:,OBp:OBendp,0],mask=mask[:,OBp:OBendp,0]),vmin=vmin,vmax=vmax,cmap=cmapi)

cbar_ax = plt.colorbar(cax0)
cbar_ax.set_label('Temperature [degC]')

p=0
for i in np.arange(0.44,0.58,0.03):
    axin.axvline(ds.Y[int(i*ny)]/1000,color=colors[p])
    p=p+1

axin.axvline(ds.Y[20]/1000,c='white',linestyle='dashed')
axin.text(0.09, 0.05, 'End of \nSponge', color='white',
        transform=axin.transAxes,fontsize=8)
axin.text(0, 1.05, '(a)', fontweight='bold', color='k',
        transform=axin.transAxes)


axin = fig.add_subplot(gs[1, 0])

V=ds.VVEL[tin,:,:,0].values - dsc.VVEL[tinc,:,:,0].values 

title= ds.VVEL.description
Yin=ds.Yp1[OBp:OBendp]
Xin=ds.X
vmin=np.min(np.ma.masked_array(V[:,OB:OBend]*100,mask=masks[:,OB:OBend,0]))
vmax=-np.min(np.ma.masked_array(V[:,OB:OBend]*100,mask=masks[:,OB:OBend,0]))
cmapi=cmocean.cm.balance

levels=np.linspace(vmin,vmax,15)

axin.set(xlabel='Distance in y [km]')
axin.set(ylabel='Depth [m]')

timein=ds.T[-tin]/(60*60*24)
cax0=axin.pcolormesh(Yin/1000, Zin, np.ma.masked_array(V[:,OBp:OBendp]*100,mask=masks[:,OBp:OBendp,0]),vmin=vmin,vmax=vmax,cmap=cmapi)

cbar_ax = plt.colorbar(cax0)
axin.axvline(ds.Y[int(0.75*ny)]/1000,c='k')
cbar_ax.set_label('Meridional\n velocity [cm/s]')
axin.axvline(ds.Y[20]/1000,c='k',linestyle='dashed')
axin.text(0.09, 0.05, 'End of \nSponge', color='k',
        transform=axin.transAxes,fontsize=8)

varin=ds.UVEL[tin].values - dsc.UVEL[tinc].values
title= ds.UVEL.description
Yin=ds.Y[OBp:OBendp]
Xin=ds.Xp1
vmin=np.min(np.mean(np.ma.masked_array(varin[:,OB:OBend,:],mask=maskw[:,OB:OBend,:]),axis=2)*100)
vmax=-np.min(np.mean(np.ma.masked_array(varin[:,OB:OBend,:],mask=maskw[:,OB:OBend,:]),axis=2)*100)
cmapi=cmocean.cm.balance

levels=np.linspace(vmin,vmax,15)

axin.text(0, 1.05, '(b)', fontweight='bold', color='k',
        transform=axin.transAxes)

axin = fig.add_subplot(gs[2, 0])

axin.set(xlabel='Distance in y [km]')
axin.set(ylabel='Depth [m]')

timein=ds.T[-tin]/(60*60*24)
cax0=axin.pcolormesh(Yin/1000, Zin, np.ma.masked_array(np.mean(varin[:,OBp:OBendp,:],axis=2)*100,mask=maskw[:,OBp:OBendp,0]),vmin=vmin,vmax=vmax,cmap=cmapi)
cbar_ax = plt.colorbar(cax0)
cbar_ax.set_label('Zonal velocity [cm/s]')

axin.axvline(ds.Y[int(0.75*ny)]/1000,c='k')
axin.text(0, 1.05, '(c)', fontweight='bold', color='k',
        transform=axin.transAxes)
axin.axvline(ds.Y[20]/1000,c='k',linestyle='dashed')
axin.text(0.09, 0.05, 'End of \nSponge', color='k',
        transform=axin.transAxes,fontsize=8)


varin=ds.WVEL[tin,:,:,0].values - dsc.WVEL[tinc,:,:,0].values #interpV((gridZ,gridY))

title= ds.WVEL.description

Yin=dsG.Y[OBp:OBendp]
Xin=ds.X
Zin=dsG.Z
vmin=np.min(np.ma.masked_array(varin[:,OB:OBend]*100,mask=mask[:,OB:OBend,0]))
vmax=-np.min(np.ma.masked_array(varin[:,OB:OBend]*100,mask=mask[:,OB:OBend,0]))
cmapi=cmocean.cm.balance
levels=np.linspace(vmin,vmax,15)

axin = fig.add_subplot(gs[3, 0])
axin.set(xlabel='Distance in y [km]')
axin.set(ylabel='Depth [m]')

timein=ds.T[-tin]/(60*60*24)
cax1=axin.pcolormesh(Yin/1000, Zin,np.ma.masked_array(varin[:,OBp:OBendp]*100,mask=mask[:,OBp:OBendp,0]),vmin=vmin,vmax=vmax,cmap=cmapi)

cbar_ax = plt.colorbar(cax1)
cbar_ax.set_label('Vertical velocity [cm/s]')

axin.axvline(ds.Y[int(0.75*ny)]/1000,c='k')

axin.axvline(ds.Y[20]/1000,c='k',linestyle='dashed')
axin.text(0.09, 0.05, 'End of \nSponge', color='k',
        transform=axin.transAxes,fontsize=8)

axin.text(0, 1.05, '(d)', fontweight='bold', color='k',
        transform=axin.transAxes)

fig.tight_layout()
fig.suptitle(f'Run with drag {str(drag)} [r]/s - run with drag {str(dragc)} [r]/s')

plt.savefig('../' + str(project)+'/Figures/' + str(drag) + 'minus' + str(dragc)+ 'crossections.png',dpi=400)

# %%
## Meridional velocity on bump ##

params = {'figure.figsize': (8, 8),
         'font.family':'sans'}
pl.rcParams.update(params)

fig,axin=plt.subplots(1,2)
ax=axin[0]
ax.plot(np.ma.masked_array(V[:,int(0.5*ny)]*100,mask=masks[:,int(0.5*ny),0]),dsG.Z,color='k',linewidth=1.5,label=f'Sum of Line: {np.sum(np.ma.masked_array(V[:,int(0.5*ny)]*100,mask=masks[:,int(0.5*ny),0])):.2e}')
ax.set(xlabel='Meridional Velocity [cm/s]',ylabel='Depth [m]')
ax.axvline(0,linewidth=1, color='r')
ax.minorticks_on()

ax.grid(which='minor',linestyle='--', alpha=0.5)
ax.grid(which='major',alpha=0.7)
ax.legend()

ax.text(0, 1.05, '(a)', fontweight='bold', color='k',
        transform=ax.transAxes)

ax=axin[1]
varin=ds.THETA
sub_ax = ax.inset_axes([0.5, 0.1, 0.7, 0.47]) #[x0, y0, width, height]
subsub_ax = sub_ax.inset_axes([0.4, 0.1, 0.8, 0.47]) #[x0, y0, width, height]
p=0
for i in np.arange(0.44,0.58,0.03):
    if np.logical_and(i<=0.5,i>=0.48):
        ax.plot(np.ma.masked_array(varin[tin,:,int(i*ny),0],mask=mask[:,int(i*ny),0]),dsG.Z,color=colors[p],linewidth=1.5,linestyle='dashed',label='On sill')
    else:
        ax.plot(np.ma.masked_array(varin[tin,:,int(i*ny),0],mask=mask[:,int(i*ny),0]),dsG.Z,color=colors[p],linewidth=1.5)
        sub_ax.plot(np.ma.masked_array(varin[tin,:,int(i*ny),0],mask=mask[:,int(i*ny),0])[dsG.Z<-600],dsG.Z[dsG.Z<-600],color=colors[p])
        subsub_ax.plot(np.ma.masked_array(varin[tin,:,int(i*ny),0],mask=mask[:,int(i*ny),0])[dsG.Z<-800],dsG.Z[dsG.Z<-800],color=colors[p])
        p=p+1

ax.set(xlabel='Potential Temperature [°C]',ylabel='Depth [m]')

ax.legend()

ax.minorticks_on()

ax.grid(which='minor',linestyle='--', alpha=0.5)
ax.grid(which='major',alpha=0.7)

sub_ax.minorticks_on()

sub_ax.grid(which='minor',linestyle='--', alpha=0.5)
sub_ax.grid(which='major',alpha=0.7)

subsub_ax.minorticks_on()

subsub_ax.grid(which='minor',linestyle='--', alpha=0.5)
subsub_ax.grid(which='major',alpha=0.7)

ax.text(0, 1.05, '(b)', fontweight='bold', color='k',
        transform=ax.transAxes)

fig.tight_layout()
#plt.savefig('IntercambioNGC/' + str(project)+'/Figures/' +str(ed)+ 'Velocity.png',dpi=400)

# %%
######## Plotting ##############

## Temperature ##

params = {'figure.figsize': (8, 4),
         'font.family':'sans'}
pl.rcParams.update(params)

fig,ax=plt.subplots()

ax.plot(ds.T.values/(60*60*24*360),np.mean(np.mean(ds.THETA[:,:zind,OB:OBend,0],axis=1),axis=1))

ax.set(xlabel='Time (Years)',ylabel='Temperature (°C)',title='Mean Temperature Over The Active Basin')

fig.tight_layout()
#plt.savefig('IntercambioNGC/' + str(project)+'/Figures/' +str(ed)+ 'OBCStest.png',dpi=400)


## Pressure ##
params = {'figure.figsize': (8, 6),
         'font.family':'sans'}
pl.rcParams.update(params)

fig,axin=plt.subplots(2)

ax=axin[0]
xlab= 'SSH [m]'
inarr=dsS.ETAN[:,:,:,:].values

ax.plot(dsS.Y[OB:OBend]/1000,np.mean(inarr[tin:,0,OB:OBend,0],axis=0), linewidth=3,c='k')
ax.set(xlabel='Distance in Y [km]',ylabel=xlab)
ax.minorticks_on()

ax.grid(which='minor',linestyle='--', alpha=0.5)
ax.grid(which='major',alpha=0.7)

g=10
rho0=1000
inarr=(np.mean((rho0*np.sum(-g*dsG.Z.values[None,:zind,None] + ds.PHIHYD.values[tin:,:zind,OB:OBend,0],axis=1)),axis=0)+g*rho0*np.mean(dsS.ETAN.values[tinSc:,0,OB:OBend,0],axis=0))/(len(dsG.Z[:zind])+1)

ax=axin[1]
xlab= 'Hydrostatic Pressure [Pa]'
ax.plot(dsG.Y[OB:OBend]/1000,inarr, linewidth=2,color='k',label='Total')

ax.set(xlabel='Distance in Y [km]',ylabel=xlab)
ax.minorticks_on()

ax.grid(which='minor',linestyle='--', alpha=0.5)
ax.grid(which='major',alpha=0.7)

fig.tight_layout()
#plt.savefig('IntercambioNGC/' + str(project)+'/Figures/' +str(ed)+ 'Pressure.png',dpi=400)
